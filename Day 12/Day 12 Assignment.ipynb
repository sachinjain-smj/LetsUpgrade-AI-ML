# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '1 Wilcoxon.xlsx',
#  '1. One Sample.xlsx',
#  'Day 12 Assignment.ipynb',
#  'Day12.ipynb',
#  'general_data.csv']

# %%
import pandas as pd

# %%
hrdataset=pd.read_csv("general_data.csv")
hrdataset.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0                 1.0      Y                11              8
# 1                 0.0      Y                23              8
# 2                 1.0      Y                15              8
# 3                 3.0      Y                11              8
# 4                 4.0      Y                12              8
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 0                 0               1.0                      6               1
# 1                 1               6.0                      3               5
# 2                 3               5.0                      2               5
# 3                 3              13.0                      5               8
# 4                 2               9.0                      2               6
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     0
# 1                        1                     4
# 2                        0                     3
# 3                        7                     5
# 4                        0                     4
#
# [5 rows x 24 columns]

# %%
hrdataset["Attrition"]=hrdataset.Attrition.map({"Yes":1,"No":0})

# %%
hrdata=hrdataset.dropna()

# %%
hrdata.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
hrdata.head()
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 1   31          1  Travel_Frequently  Research & Development
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# 1                10          1  Life Sciences              1           2
# 2                17          4          Other              1           3
# 3                 2          5  Life Sciences              1           4
# 4                10          1        Medical              1           5
#
#    Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0  Female  ...                 1.0      Y                11              8
# 1  Female  ...                 0.0      Y                23              8
# 2    Male  ...                 1.0      Y                15              8
# 3    Male  ...                 3.0      Y                11              8
# 4    Male  ...                 4.0      Y                12              8
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 0                 0               1.0                      6               1
# 1                 1               6.0                      3               5
# 2                 3               5.0                      2               5
# 3                 3              13.0                      5               8
# 4                 2               9.0                      2               6
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     0
# 1                        1                     4
# 2                        0                     3
# 3                        7                     5
# 4                        0                     4
#
# [5 rows x 24 columns]

# %% [markdown]
# # Wilcoxon test is used to compare 2 paired samples

# %%
hrdatapaired=hrdata[hrdata["Attrition"]==1]
hrdatapaired.head()
# Out:
#     Age  Attrition     BusinessTravel              Department  \
# 1    31          1  Travel_Frequently  Research & Development
# 6    28          1      Travel_Rarely  Research & Development
# 13   47          1         Non-Travel  Research & Development
# 28   44          1  Travel_Frequently  Research & Development
# 30   26          1      Travel_Rarely  Research & Development
#
#     DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 1                 10          1  Life Sciences              1           2
# 6                 11          2        Medical              1           7
# 13                 1          1        Medical              1          14
# 28                 1          2        Medical              1          29
# 30                 4          3        Medical              1          31
#
#     Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 1   Female  ...                 0.0      Y                23              8
# 6     Male  ...                 2.0      Y                20              8
# 13    Male  ...                 1.0      Y                11              8
# 28    Male  ...                 3.0      Y                14              8
# 30    Male  ...                 2.0      Y                11              8
#
#     StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 1                  1               6.0                      3               5
# 6                  1               5.0                      2               0
# 13                 2              10.0                      4              10
# 28                 1              19.0                      2               1
# 30                 0               5.0                      5               3
#
#     YearsSinceLastPromotion  YearsWithCurrManager
# 1                         1                     4
# 6                         0                     0
# 13                        9                     9
# 28                        0                     0
# 30                        0                     2
#
# [5 rows x 24 columns]

# %%
from scipy.stats import wilcoxon

# %% [markdown]
# # Hypothesis
#
# Ho= There is no significant difference between Percent Salary Hike and Total Working Years.
#
# Ha= There is significant difference between Percent Salary Hike and Total Working Years.

# %%
stats,p=wilcoxon(hrdatapaired.PercentSalaryHike,hrdatapaired.TotalWorkingYears)
print(stats,p)
# Out:
# 27759.0 1.4168286858871556e-69

# %% [markdown]
# # Since p<0.05 we reject Ho and Accept Ha

# %% [markdown]
# # Friedman Test is used to compare more than 2 paired samples.

# %%
from scipy.stats import friedmanchisquare

# %% [markdown]
# # Hypothesis
#
# Ho= There is no significant difference between Percent Salary Hike, Total Working Years and Years at Company.
#
# Ha= There is significant difference between Percent Salary Hike, Total Working Years and Years at Company.

# %%
stats,p = friedmanchisquare(hrdatapaired.PercentSalaryHike,hrdatapaired.TotalWorkingYears,hrdatapaired.YearsAtCompany)
print(stats, p)
# Out:
# 912.2680331099739 8.0078070801161535e-199

# %% [markdown]
# # Since p<0.05 we reject Ho and Accept Ha

# %% [markdown]
# # Mannwhitney Test is used to compare to independent samples

# %%
from scipy.stats import mannwhitneyu

# %% [markdown]
# # Hypothesis
# Ho= There is no significant difference between Age and Total Working Years.
#
# Ha= There is significant difference between Age and Total Working Years.

# %%
stats,p = mannwhitneyu(hrdatapaired.Age,hrdatapaired.TotalWorkingYears)
print(stats,p)
# Out:
# 10641.0 3.913461082441059e-213

# %% [markdown]
# # Since p<0.05 we reject Ho and Accept Ha

# %% [markdown]
# # Kruskal wallis is used to compare to more than two independent samples

# %%
from scipy.stats import kruskal

# %% [markdown]
# # Hypothesis
# Ho= There is no significant difference between Number of Companies Worked, Total Working Years and Training Times Last Year.
#
# Ha= There is significant difference between Number of Companies Worked, Total Working Years and Training Times Last Year.

# %%
stats,p = kruskal(hrdatapaired.NumCompaniesWorked,hrdatapaired.TotalWorkingYears,hrdatapaired.TrainingTimesLastYear)
print(stats,p)
# Out:
# 426.01993209496675 3.097042429103304e-93

# %% [markdown]
# # Since p<0.05 we reject Ho and Accept Ha

# %% [markdown]
# # Chi Square Test is used to check the dependency of variable and variable should be categorical

# %%
from scipy.stats import chi2_contingency

# %% [markdown]
# # Hypothesis
# Ho= There is no significant difference between Gender and Attrition.
#
# Ha= There is significant difference between Gender and Attrition.

# %%
chitable=pd.crosstab(hrdataset.Gender,hrdataset.Attrition)
chitable
# Out:
# Attrition     0    1
# Gender
# Female     1494  270
# Male       2205  441

# %%
stats,p,dof,expected=chi2_contingency(chitable)
print(stats,p)
# Out:
# 1.349904410246582 0.24529482862926827

# %% [markdown]
# # Since p>0.05 we accept Ho and reject Ha
