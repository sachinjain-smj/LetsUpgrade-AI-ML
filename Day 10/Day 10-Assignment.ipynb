# %% [markdown]
# 10 Hypothesis Examples

# %% [markdown]
# 1. The middle class people spend on average Rs. 20000 on vacation per year.
# Assume sd = 1500

# %% [markdown]
# 2. In India people do not like to spend more than Rs. 200 per month on phone bill

# %% [markdown]
# 3. Teenagers take less than 1 hr to become familiar with technology. Assume sd= 20 mins

# %% [markdown]
# 4. Every household in India has atleast 4 members.

# %% [markdown]
# 5. Every India has atleast 1 vehicle at home

# %% [markdown]
# 6. Indian spends on an average 120  mins daily on reading, assume sd=15 mins

# %% [markdown]
# 7. Globally people spend on an average USD 1000 on health per year, assume sd = USD 100

# %% [markdown]
# 8. Average Life Span in india is atleast 70 years

# %% [markdown]
# 9. Indian houshold have atleast 4 smartphones in their home, sd= 1

# %% [markdown]
# 10. Indian spend atleast Rs. 40000 per year on education, assume sd= Rs. 3000
